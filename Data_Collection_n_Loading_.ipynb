# %% [markdown]
# <a href="https://colab.research.google.com/github/wtryab-re/machine-learning-reboost/blob/main/Data_Collection_n_Loading_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Install the Libraries

# %%
# !pip install -q pandas numpy seaborn matplotlib

# %% [markdown]
# pyarrow are used for parquet files
#
# Parquet files are used when the data is extremely large, so it compresses it.
#
# openpyxl are used for excel files
# used for excel sheet manipulation, NOT like pandas at all.
#
# Pandas used for analysis work only

# %%
# !pip install -q pyarrow openpyxl

# %% [markdown]
# Import the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ##Titanic(1) CSV

# %%
titanic_dataset = pd.read_csv("titanic (1).csv")
titanic_dataset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Load selected columns

# %%
titanic_dataset_selected = pd.read_csv("titanic (1).csv", usecols=["PassengerId"])
titanic_dataset_selected.head(2)
# Out:
#    PassengerId
# 0            1
# 1            2

# %% [markdown]
# Load selected rows

# %%
titanic_dataset_selected = pd.read_csv("titanic (1).csv", nrows=20)
titanic_dataset_selected.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ##Titanic Tab CSV

# %%
titanic_tab = pd.read_csv("/content/titanic_tab.csv",sep="\t")
titanic_tab.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ##Excel

# %%
titanic_excel = pd.read_excel("/content/titanic.xlsx")
titanic_excel.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Load selected columns

# %%
titanic_excel_selected = pd.read_excel("/content/titanic.xlsx", usecols=["PassengerId"])
titanic_excel_selected.head(2)
# Out:
#    PassengerId
# 0            1
# 1            2

# %% [markdown]
# Load Selected Rows

# %%
titanic_excel_selected = pd.read_excel("/content/titanic.xlsx", nrows=20)
titanic_excel_selected.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Select Specific Sheet in Excel

# %%
#sheet names
excel_sheet = pd.ExcelFile("titanic.xlsx")
excel_sheet.sheet_names
# Out:
# ['Sheet1']

# %%
#open w the sheet name
titanic_excel_sheet = pd.read_excel(excel_sheet, sheet_name="Sheet1")
titanic_excel_sheet.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ##Titanic Parquet
# Parquet files are used when the data is extremely large, so it compresses it.

# %%
titanic_parquet = pd.read_parquet("/content/titanic.parquet")
titanic_parquet.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500  None        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# #Check file sizes

# %%
file_size = os.stat("titanic.xlsx").st_size
print(f"Size: {file_size} bytes")
# Out:
# Size: 68829 bytes

# %% [markdown]
# #Kaggle

# %% [markdown]
# oh kaggle pisses me off, its so complex for NO reason

# %% [markdown]
# ##Kaggle

# %% [markdown]
# Way 1 to download kaggle datasets

# %%
# !pip install -q kagglehub[pandas-datasets]

# %%
# Install dependencies as needed:
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "annual-number-of-deaths-by-cause.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "programmerrdai/cancer",
  file_path
)

# %% [markdown]
# ##Way 2

# %%
# !kaggle datasets download programmerrdai/cancer
# Out:
# Dataset URL: https://www.kaggle.com/datasets/programmerrdai/cancer
# License(s): CC0-1.0
# ...
# 100% 7.84M/7.84M [00:01<00:00, 5.84MB/s]

# %%
import zipfile

# %%
fil = zipfile.ZipFile("cancer.zip","r")
fil.extractall("/content")
fil.close()

# %% [markdown]
# ##UCI Datasets

# %%
# !pip install -q ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
wine_quality = fetch_ucirepo(id=186)

# data (as pandas dataframes)
X = wine_quality.data.features
y = wine_quality.data.targets

# metadata
print(wine_quality.metadata)

# variable information
print(wine_quality.variables)

# %% [markdown]
# ##API TOKEN SAVING

# %%
import os

# %%
os.environ["Kaggle_User"] = "CUZIALWAYSHADAVISIONOFUSSTANDINGLIKETHIS"

# %% [markdown]
# ##Database Retrieval

# %% [markdown]
# When getting data from a DB

# %% [markdown]
#  Install any Relational DB Server

# %% [markdown]
# Install Dbeaver

# %%
#installings if using postgres
# !pip install -q SQLAlchemy psycopg2-binary

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
connection_string = "postgresql://username:password@host:port/dbname"
engine = create_engine(connection_string)

# %%
df = pd.read_sql(
    sql="SELECT * FROM table_name",
    con=engine
)

# %% [markdown]
# #JSON/SQL FORMAT DATA

# %%
# !kaggle datasets download nurahmed12/json-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nurahmed12/json-dataset
# License(s): unknown
# ...
# 100% 1.80M/1.80M [00:01<00:00, 1.59MB/s]

# %%
import zipfile
import pandas as pd
unzip = zipfile.ZipFile("json-dataset.zip", "r")

# %%
unzip.extractall("data/")
unzip.close()

# %%
df = pd.read_json("data/train.json")
df.head()
df.shape
# Out:
# (39774, 3)

# %%
pd.read_json("add an api link and it works the SAME")

# %% [markdown]
# ##SQL

# %%
# !kaggle datasets download hashtagkehl/worldsql
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hashtagkehl/worldsql
# License(s): unknown
# ...
# 100% 787/787 [00:00<00:00, 2.45MB/s]

# %%
import zipfile
fil = zipfile.ZipFile("worldsql.zip", "r")
fil.extractall("data/")
fil.close()

# %%
# !pip install mysql.connector
import mysql.connector
conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "password",
    database = "world"
)

df = pd.read_sql_query("SELECT * FROM COUNTRY WHERE X = 10", conn)

# %% [markdown]
# ##API - getting data from an api

# %%
# !pip install -q requests

# %%
import requests
import os
import pandas as pd

url = "https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1"
os.environ["TMDBRATOKEN"]= "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1NDA4Y2I3ZjU2ZTk4MmU1MGI0ODc2ZTdhNzQ3ZmZlNSIsIm5iZiI6MTc0MTcxODM0MC4wNjcwMDAyLCJzdWIiOiI2N2QwODM0NDQzNGM5OGM4ZWM4MTNmMjAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.Mdwpk-Uk9s0iYA90z_19lBB3qpPAHKBh0aUhZ5Ifu4M"
headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {os.environ["TMDBRATOKEN"]}" }

# %%
response = requests.get(url, headers=headers)
data = response.json()
df = pd.DataFrame(data["results"],columns=["id", "name", "overview", "first_air_date", "vote_count", "vote_average"])
data["results"]

# %%
headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {os.environ["TMDBRATOKEN"]}" }
newdf = pd.DataFrame()
for index in range(1,8):
  url = f"https://api.themoviedb.org/3/tv/top_rated?language=en-US&page={index}"
  response = requests.get(url, headers=headers)
  data = response.json()
  ogdf = pd.DataFrame(data["results"],columns=["id", "name", "overview", "first_air_date", "vote_count", "vote_average"])
  newdf = pd.concat([newdf, ogdf], ignore_index=True)
newdf.shape
newdf.head()
# Out:
#        id                           name  \
# 0    1396                   Breaking Bad
# 1  209867  Frieren: Beyond Journey's End
# 2   64010                     Reply 1988
# 3     246     Avatar: The Last Airbender
# 4   94605                         Arcane
#
#                                             overview first_air_date  \
# 0  Walter White, a New Mexico chemistry teacher, ...     2008-01-20
# 1  After the party of heroes defeated the Demon K...     2023-09-29
# 2  Take a nostalgic trip back to the late 1980s t...     2015-11-06
# 3  In a war-torn world of elemental magic, a youn...     2005-02-21
# 4  Amid the stark discord of twin cities Piltover...     2021-11-06
#
#    vote_count  vote_average
# 0       17644         8.942
# 1         797         8.799
# 2         207         8.800
# 3        4793         8.757
# 4        5847         8.753

# %%
newdf.shape
# Out:
# (140, 6)

# %% [markdown]
# #Web Scraping

# %%
# !pip install -q requests beautifulsoup4

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.zameen.com/Homes/Islamabad_DHA_Defence-3188-1.html"
#incase you cannot access the site because the site blacklists bots. so you add this header.
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)

# %%
bs = BeautifulSoup(response.text, "lxml")

# %%
price = bs.find_all("span", class_="dc381b54")
print(len(price))

location = bs.find_all("div", class_="db1aca2f", attrs={"aria-label":"Location"})
print(len(location))

baths= bs.find_all("span", class_="_6d9b9b83", attrs={"aria-label":"Baths"})
print(len(baths))

beds= bs.find_all("span", class_="_6d9b9b83", attrs={"aria-label":"Beds"})
print(len(beds))

zameen = pd.DataFrame()
print(price)

for i in range(len(price)):
  zameen.loc[i, "price"] = price[i].text
print(location)
for i in range(len(location)):
  zameen.loc[i, "location"] = location[i].text
print(baths)
for i in range(len(baths)):
  zameen.loc[i, "baths"] = baths[i].text
print(beds)
for i in range(len(beds)):
  zameen.loc[i, "beds"] = beds[i].text

zameen
# Out:
# 25
# 25
# 25
# 23
# ...
