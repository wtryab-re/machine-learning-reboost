# %% [markdown]
# <a href="https://colab.research.google.com/github/wtryab-re/machine-learning-reboost/blob/main/What's_your_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandas numpy scikit-learn seaborn matplotlib

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
pd.set_option('display.float_format',"{:.2f}".format)

# %%
pd.reset_option("display.float_format")

# %%
df = load_iris(as_frame=True)["frame"]
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
df.corr()

# %%
sns.heatmap(df.corr(), cmap="coolwarm", linewidths=0.5, annot=True)

# %%
pip install -q fg-data-profiling

# %%
import data_profiling
from data_profiling import ProfileReport

# %%
ProfileReport(df)
